# %%
import os
import requests
from bs4 import BeautifulSoup
import shutil
import re
import time
import random

# Constants
BASE_URL = "https://www.greenclimate.fund/"
PROJECTS_PAGE = "https://www.greenclimate.fund/project/"
PROJECTS_FOLDER = "GCF_docs"



if __name__ == "__main__":
    scrape_af_documents()
# Out:
# Attempting to download https://fifspubprd.azureedge.net/afdocuments/project/15070/SPC_Nauru_Resubmission_Clean.pdf to AF_docs\RCFAAIN_82_SPC_Nauru_Resubmission_Clean.pdf
# Downloaded https://fifspubprd.azureedge.net/afdocuments/project/15070/SPC_Nauru_Resubmission_Clean.pdf to AF_docs\RCFAAIN_82_SPC_Nauru_Resubmission_Clean.pdf
# Attempting to download https://www.adaptation-fund.org/projects-document-view?URL=https://spxdocs/en/081200010182228058/15051_Mongolia AF Concept Note August 2022 - For submission clean.pdf to AF_docs\GCRP_60_15051_Mongolia AF Concept Note August 2022 - For submission clean.pdf
# Downloaded https://www.adaptation-fund.org/projects-document-view?URL=https://spxdocs/en/081200010182228058/15051_Mongolia AF Concept Note August 2022 - For submission clean.pdf to AF_docs\GCRP_60_15051_Mongolia AF Concept Note August 2022 - For submission clean.pdf
# ...
